# %%
# ALWAYS RUN

import sys, os, distutils.core


# INSTALL detectron 2 
# !python3 -m pip install pyyaml==5.1
# Note: This is a faster way to install detectron2 in Colab, but it does not include all functionalities.
# See https://detectron2.readthedocs.io/tutorials/install.html for full installation instructions
# !git clone 'https://github.com/facebookresearch/detectron2'
dist = distutils.core.run_setup("./detectron2/setup.py")
# !python3 -m pip install {' '.join([f"'{x}'" for x in dist.install_requires])}



#### ONLY FIRST TIME

# Properly install detectron2. (Please do not install twice in both ways)
#!python3 -m pip install 'git+https://github.com/facebookresearch/detectron2.git'


sys.path.insert(0, os.path.abspath('./detectron2'))
# Out:
# ...
# fatal: le chemin de destination 'detectron2' existe déjà et n'est pas un répertoire vide.
# ...

# %%
# !python3 -m pip install -r SMILEtrack/BoT-SORT/requirements.txt
# Out:
# ...
#   Using cached scikit_image-0.20.0-cp310-cp310-macosx_12_0_arm64.whl (12.7 MB)
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# ...
#   Using cached ninja-1.11.1-py2.py3-none-macosx_10_9_universal2.macosx_10_9_x86_64.macosx_11_0_arm64.macosx_11_0_universal2.whl (270 kB)
# ...
#   Using cached lap-0.4.0.tar.gz (1.5 MB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached filterpy-1.4.5.zip (177 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached prettytable-3.6.0-py3-none-any.whl (27 kB)
# ...
#   Using cached easydict-1.10.tar.gz (6.4 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached gdown-4.6.4-py3-none-any.whl (14 kB)
# ...
#   Using cached onnx-1.8.1.tar.gz (5.2 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [18 lines of output]
# ...

# %%
# !python3 -m pip install thop
# !python3 -m pip install lap
# !python3 -m pip install cython_bbox
# !python3 -m pip install faiss-cpu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 41.1 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# !python3 -m pip install -r SMILEtrack/BoT-SORT/fast_reid/docs/requirements.txt
# Out:
# ...
#   Using cached prettytable-3.6.0-py3-none-any.whl (27 kB)
# ...
#   Using cached easydict-1.10.tar.gz (6.4 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached gdown-4.6.4-py3-none-any.whl (14 kB)
# ...
#   Using cached faiss-gpu-1.7.1.post2.tar.gz (40 kB)
#   Preparing metadata (setup.py) ... done
#   WARNING: Generating metadata for package faiss-gpu produced metadata for project name faiss-cpu. Fix your #egg=faiss-gpu fragments.
# Discarding https://files.pythonhosted.org/packages/17/76/47d0cc8161f4bf988583a2839bb1e56baf09d6b80cfa472b9eba4d5f543b/faiss-gpu-1.7.1.post2.tar.gz (from https://pypi.org/simple/faiss-gpu/): Requested faiss-cpu from https://files.pythonhosted.org/packages/17/76/47d0cc8161f4bf988583a2839bb1e56baf09d6b80cfa472b9eba4d5f543b/faiss-gpu-1.7.1.post2.tar.gz (from -r SMILEtrack/BoT-SORT/fast_reid/docs/requirements.txt (line 20)) has inconsistent name: expected 'faiss-gpu', but metadata has 'faiss-cpu'
#   Using cached faiss-gpu-1.7.1.post1.tar.gz (41 kB)
# ...

# %%
# !python3 DiffusionTrack.py --config-file configs/diffdet.mot.swinbase.yaml --input "datasets/mot/train/*FRCNN/img1" --output "output_PRIOR/CrowdHuman_random" --confidence-threshold 0.1 --opts MODEL.WEIGHTS output/model_0054999.pth MODEL.DiffusionDet.SAMPLE_STEP 8
# Out:
# Traceback (most recent call last):
#   File "/Users/gabrielfiastre/Github/DiffusionTrack/DiffusionTrack.py", line 40, in <module>
#     from tracker.bot_sort import BoTSORT
#   File "/Users/gabrielfiastre/Github/DiffusionTrack/SMILEtrack/BoT-SORT/tracker/bot_sort.py", line 11, in <module>
#     from fast_reid.fast_reid_interfece import FastReIDInterface
#   File "/Users/gabrielfiastre/Github/DiffusionTrack/SMILEtrack/BoT-SORT/fast_reid/fast_reid_interfece.py", line 11, in <module>
#     from fast_reid.fastreid.engine import DefaultTrainer, default_argument_parser, default_setup, launch
#   File "/Users/gabrielfiastre/Github/DiffusionTrack/SMILEtrack/BoT-SORT/fast_reid/fastreid/engine/__init__.py", line 13, in <module>
#     from .hooks import *
#   File "/Users/gabrielfiastre/Github/DiffusionTrack/SMILEtrack/BoT-SORT/fast_reid/fastreid/engine/hooks.py", line 16, in <module>
#     from fast_reid.fastreid.evaluation.testing import flatten_results_dict
# ...

# %%
# !python3 -m pip install pytorch
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [6 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/fs/pl0bq7c97j7ddng3nfms3k840000gn/T/pip-install-d5qxp9hi/pytorch_75f8c6bfb30f4ecbae925a877b90249d/setup.py", line 15, in <module>
#           raise Exception(message)
#       Exception: You tried to install "pytorch". The package named for PyTorch is "torch"
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pytorch
#   Running setup.py clean for pytorch
# Failed to build pytorch
# ...
#   Running setup.py install for pytorch ... error
#   error: subprocess-exited-with-error
#
# ...

# %%
# !python3 demo.py '../MOT17/train/MOT17-02-FRCNN/img1/' --device cuda --output-dir "DEMO" --config-file DiffusionDet/configs/diffdet.mot.swinbase.yaml --opts MODEL.WEIGHTS DiffusionDet/models/model_0064999.pth MODEL.DiffusionDet.SAMPLE_STEP 8
# Out:
# [03/18 12:58:02 DiffTrack]: Arguments: Namespace(path='../MOT17/train/MOT17-02-FRCNN/img1/', output_dir='DEMO', save_det=True, save_frames=False, det_folder='', config_file='DiffusionDet/configs/diffdet.mot.swinbase.yaml', confidence_threshold=0.1, class_id=0, opts=['MODEL.WEIGHTS', 'DiffusionDet/models/model_0064999.pth', 'MODEL.DiffusionDet.SAMPLE_STEP', '8'], device='cuda', with_reid=False, benchmark='MOT17', eval='test', f=None, c=None, ablation=False, experiment_name='DEMO', default_parameters=False, conf=None, nms=None, tsize=None, fp16=False, fuse=False, track_high_thresh=0.6, track_low_thresh=0.1, new_track_thresh=0.7, track_buffer=30, match_thresh=0.8, aspect_ratio_thresh=1.6, min_box_area=10, cmc_method='none', fast_reid_config='fast_reid/configs/MOT17/sbs_S50.yml', fast_reid_weights='pretrained/mot17_sbs_S50.pth', proximity_thresh=0.5, appearance_thresh=0.25)
# [03/18 12:58:02 DiffTrack]: Device : cpu
# ...
